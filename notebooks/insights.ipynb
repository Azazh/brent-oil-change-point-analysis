# %%
import sys
import os

# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now you can import from src
from src.models import fit_arima, fit_garch

import pandas as pd

# Load processed data
data = pd.read_csv('../data/processed_brent_oil_prices.csv', parse_dates=['Date'], index_col='Date')

# Fit ARIMA model
arima_results = fit_arima(data['Price'])

# Fit GARCH model
garch_results = fit_garch(data['Price'])

# Summarize findings
print("ARIMA Model Summary:")
print(arima_results.summary())

print("\nGARCH Model Summary:")
print(garch_results.summary())
# Out:
# /home/azazh/Documents/10-acadamy/w-10/Analyzing_Oil_Price_Changes_with_Event_Impact/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/azazh/Documents/10-acadamy/w-10/Analyzing_Oil_Price_Changes_with_Event_Impact/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/azazh/Documents/10-acadamy/w-10/Analyzing_Oil_Price_Changes_with_Event_Impact/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 97378349170.75806
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 70149.2042068351
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 1851811015.0339441
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 44034.729057607685
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 43698.83708600999
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 46134.33970540376
# Iteration:      7,   Func. Count:     45,   Neg. LLF: 39816.66774832398
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 42848.420329461354
# Iteration:      9,   Func. Count:     57,   Neg. LLF: 35637.13926185758
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 41279.10043111231
# Iteration:     11,   Func. Count:     68,   Neg. LLF: 39707.41740071211
# Iteration:     12,   Func. Count:     77,   Neg. LLF: 35582.89771940086
# Iteration:     13,   Func. Count:     83,   Neg. LLF: 35540.59359118322
# Iteration:     14,   Func. Count:     89,   Neg. LLF: 35231.0002014047
# Iteration:     15,   Func. Count:     94,   Neg. LLF: 36111.518035308014
# Iteration:     16,   Func. Count:    101,   Neg. LLF: 35254.977509730175
# Iteration:     17,   Func. Count:    107,   Neg. LLF: 35214.62586795849
# Iteration:     18,   Func. Count:    112,   Neg. LLF: 35212.02904280157
# Iteration:     19,   Func. Count:    117,   Neg. LLF: 35210.30134841942
# Iteration:     20,   Func. Count:    122,   Neg. LLF: 35210.246540974316
# Iteration:     21,   Func. Count:    127,   Neg. LLF: 35210.2437293003
# Iteration:     22,   Func. Count:    132,   Neg. LLF: 35210.24345378155
# Iteration:     23,   Func. Count:    137,   Neg. LLF: 35210.243452903174
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 35210.243452903174
#             Iterations: 23
#             Function evaluations: 137
#             Gradient evaluations: 23
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 9011
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -14540.613
# Date:                Sat, 22 Feb 2025   AIC                          29093.226
# Time:                        12:40:03   BIC                          29135.862
# Sample:                             0   HQIC                         29107.733
#                                - 9011
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0260      0.006      4.344      0.000       0.014       0.038
# ar.L2         -0.0235      0.006     -4.231      0.000      -0.034      -0.013
# ar.L3         -0.0071      0.005     -1.507      0.132      -0.016       0.002
# ar.L4          0.0198      0.006      3.423      0.001       0.008       0.031
# ar.L5         -0.0026      0.005     -0.503      0.615      -0.013       0.008
# sigma2         1.4767      0.008    174.914      0.000       1.460       1.493
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             66733.09
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.11   Skew:                            -0.67
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# GARCH Model Summary:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -35210.2
# Distribution:                  Normal   AIC:                           70428.5
# Method:            Maximum Likelihood   BIC:                           70456.9
#                                         No. Observations:                 9011
# Date:                Sat, Feb 22 2025   Df Residuals:                     9010
# Time:                        12:40:03   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu            18.6326  8.477e-02    219.795      0.000 [ 18.466, 18.799]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0756  1.511e-02      5.004  5.618e-07 [4.598e-02,  0.105]
# alpha[1]       0.8311  6.431e-02     12.924  3.296e-38   [  0.705,  0.957]
# beta[1]        0.1689  6.472e-02      2.609  9.078e-03 [4.201e-02,  0.296]
# ==========================================================================
#
# Covariance estimator: robust
